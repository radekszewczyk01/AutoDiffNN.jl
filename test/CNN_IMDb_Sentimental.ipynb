# %%
using Pkg
using Random
using LinearAlgebra
using Printf
using myExample
using Optimisers
using JLD2, Statistics

const AD = myExample.AutoDiff
const MF = myExample.MiniFlux

Random.seed!(123)

println("Loading dataset...")
data_path_prefix = "../data/"
try
    global X_train = load(joinpath(data_path_prefix, "imdb_dataset_prepared.jld2"), "X_train")
    global y_train = load(joinpath(data_path_prefix, "imdb_dataset_prepared.jld2"), "y_train")
    global X_test = load(joinpath(data_path_prefix, "imdb_dataset_prepared.jld2"), "X_test")
    global y_test = load(joinpath(data_path_prefix, "imdb_dataset_prepared.jld2"), "y_test")
    global embeddings = load(joinpath(data_path_prefix, "imdb_dataset_prepared.jld2"), "embeddings")
    global vocab = load(joinpath(data_path_prefix, "imdb_dataset_prepared.jld2"), "vocab")
catch e
    println("Error loading data: $e"); exit()
end

println("Dataset loaded. X_train size: $(size(X_train)), y_train size: $(size(y_train))")

embedding_dim = size(embeddings, 1)
vocab_size    = length(vocab)
max_seq_len   = size(X_train, 1)

W_out_conv = max_seq_len - 3 + 1
if W_out_conv < 8
    error("Output width after Conv1D ($W_out_conv) is less than MaxPool1D pool size (8).")
end
W_out_pool = div(W_out_conv - 8, 8) + 1
actual_dense_input_features = W_out_pool * 8

model = MF.chain(
    MF.Embedding(vocab_size, embedding_dim),
    x -> AD.PermuteDimsOp(x, (2, 1, 3)),
    MF.Conv1D((3,), embedding_dim => 8, activation=AD.relu),
    MF.MaxPool1D((8,)),
    MF.Flatten(),
    MF.Dense(actual_dense_input_features, 1, AD.σ)
)

if model.layers[1] isa MF.Embedding
    target_size = size(model.layers[1].W.output)
    source_size = size(embeddings)
    if target_size == source_size
        model.layers[1].W.output .= embeddings
        println("Embeddings assigned to model.")
    else
        println("Error: Embeddings matrix size $source_size does not match model embedding layer size $target_size.")
    end
else
    println("Error: First layer is not an Embedding layer.")
end

batchsize = 64
train_loader = MF.create_batches(X_train, y_train, batchsize)
test_loader = MF.create_batches(X_test, y_test, batchsize)

learning_rate = 0.01f0
opt_rule = Optimisers.Adam(learning_rate)
epochs = 4

MF.train_with_optimisers!(model, MF.binary_cross_entropy_loss,
                          train_loader, test_loader,
                          opt_rule, epochs)
println("Training finished."); flush(stdout)
# Out:
# Loading dataset...
# Dataset loaded. X_train size: (130, 40000), y_train size: (1, 40000)
# Embeddings assigned to model.
#
# Starting training...
#
# ===== Starting Epoch 1/4 =====
# Epoch 1, Batch 62/625: Loss: 0.7211, Time/Batch: 0.033s
# Epoch 1, Batch 124/625: Loss: 0.6915, Time/Batch: 0.036s
# Epoch 1, Batch 186/625: Loss: 0.7335, Time/Batch: 0.028s
# Epoch 1, Batch 248/625: Loss: 0.6805, Time/Batch: 0.028s
# Epoch 1, Batch 310/625: Loss: 0.6814, Time/Batch: 0.028s
# Epoch 1, Batch 372/625: Loss: 0.6853, Time/Batch: 0.031s
# Epoch 1, Batch 434/625: Loss: 0.6766, Time/Batch: 0.026s
# Epoch 1, Batch 496/625: Loss: 0.6652, Time/Batch: 0.031s
# Epoch 1, Batch 558/625: Loss: 0.6558, Time/Batch: 0.028s
# Epoch 1, Batch 620/625: Loss: 0.6668, Time/Batch: 0.033s
# Epoch 1, Batch 625/625: Loss: 0.7181, Time/Batch: 0.035s
# Epoch 1: Calculating accuracies...
# EPOCH 1 SUMMARY: Avg Loss: 0.7415, Train Acc: 61.78%, Val Acc: 58.43%, Epoch Time: 40.61s (Avg Batch: 0.065s)
# =====================================
# ===== Starting Epoch 2/4 =====
# Epoch 2, Batch 62/625: Loss: 0.5541, Time/Batch: 0.030s
# Epoch 2, Batch 124/625: Loss: 0.6367, Time/Batch: 0.034s
# Epoch 2, Batch 186/625: Loss: 0.5556, Time/Batch: 0.029s
# Epoch 2, Batch 248/625: Loss: 0.4665, Time/Batch: 0.037s
# Epoch 2, Batch 310/625: Loss: 0.5978, Time/Batch: 0.028s
# Epoch 2, Batch 372/625: Loss: 0.3711, Time/Batch: 0.034s
# Epoch 2, Batch 434/625: Loss: 0.4626, Time/Batch: 0.026s
# Epoch 2, Batch 496/625: Loss: 0.4359, Time/Batch: 0.033s
# Epoch 2, Batch 558/625: Loss: 0.4716, Time/Batch: 0.039s
# Epoch 2, Batch 620/625: Loss: 0.2791, Time/Batch: 0.030s
# Epoch 2, Batch 625/625: Loss: 0.4602, Time/Batch: 0.028s
# Epoch 2: Calculating accuracies...
# EPOCH 2 SUMMARY: Avg Loss: 0.5171, Train Acc: 87.36%, Val Acc: 83.36%, Epoch Time: 19.71s (Avg Batch: 0.032s)
# =====================================
# ===== Starting Epoch 3/4 =====
# Epoch 3, Batch 62/625: Loss: 0.2430, Time/Batch: 0.033s
# Epoch 3, Batch 124/625: Loss: 0.2884, Time/Batch: 0.028s
# Epoch 3, Batch 186/625: Loss: 0.2573, Time/Batch: 0.025s
# Epoch 3, Batch 248/625: Loss: 0.1463, Time/Batch: 0.028s
# Epoch 3, Batch 310/625: Loss: 0.4139, Time/Batch: 0.034s
# Epoch 3, Batch 372/625: Loss: 0.2501, Time/Batch: 0.028s
# Epoch 3, Batch 434/625: Loss: 0.2935, Time/Batch: 0.029s
# Epoch 3, Batch 496/625: Loss: 0.2588, Time/Batch: 0.029s
# Epoch 3, Batch 558/625: Loss: 0.2865, Time/Batch: 0.029s
# Epoch 3, Batch 620/625: Loss: 0.1767, Time/Batch: 0.025s
# Epoch 3, Batch 625/625: Loss: 0.2912, Time/Batch: 0.029s
# Epoch 3: Calculating accuracies...
# EPOCH 3 SUMMARY: Avg Loss: 0.3027, Train Acc: 91.88%, Val Acc: 84.78%, Epoch Time: 19.61s (Avg Batch: 0.031s)
# =====================================
# ===== Starting Epoch 4/4 =====
# Epoch 4, Batch 62/625: Loss: 0.1897, Time/Batch: 0.033s
# Epoch 4, Batch 124/625: Loss: 0.1873, Time/Batch: 0.034s
# Epoch 4, Batch 186/625: Loss: 0.1140, Time/Batch: 0.034s
# Epoch 4, Batch 248/625: Loss: 0.0997, Time/Batch: 0.030s
# Epoch 4, Batch 310/625: Loss: 0.2808, Time/Batch: 0.030s
# Epoch 4, Batch 372/625: Loss: 0.1525, Time/Batch: 0.036s
# Epoch 4, Batch 434/625: Loss: 0.1220, Time/Batch: 0.034s
# Epoch 4, Batch 496/625: Loss: 0.1989, Time/Batch: 0.026s
# Epoch 4, Batch 558/625: Loss: 0.1244, Time/Batch: 0.028s
# Epoch 4, Batch 620/625: Loss: 0.1409, Time/Batch: 0.030s
# Epoch 4, Batch 625/625: Loss: 0.3423, Time/Batch: 0.033s
# Epoch 4: Calculating accuracies...
# EPOCH 4 SUMMARY: Avg Loss: 0.2049, Train Acc: 94.85%, Val Acc: 85.40%, Epoch Time: 20.38s (Avg Batch: 0.033s)
# =====================================
# <<<<< train_with_optimisers! function finished >>>>>
# Training finished.
